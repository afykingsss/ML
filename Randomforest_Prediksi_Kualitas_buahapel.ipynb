# %% [markdown]
# <a href="https://colab.research.google.com/github/afykingsss/ML/blob/main/Randomforest_Prediksi_Kualitas_buahapel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import numpy as np

# %%
df=pd.read_csv("apple_quality.csv")
df = df.drop(['A_id'], axis=1)
df
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity Quality
# 0    -0.491590    good
# 1    -0.722809    good
# 2     2.621636     bad
# 3     0.790723    good
# ...

# %%
scaler= MinMaxScaler()
scaled=scaler.fit_transform(df[['Size','Weight','Sweetness','Crunchiness','Juiciness','Ripeness','Acidity']])

scaled_df = pd.DataFrame(scaled, columns=('Size','Weight','Sweetness','Crunchiness','Juiciness','Ripeness','Acidity'))
df[['Size','Weight','Sweetness','Crunchiness','Juiciness','Ripeness','Acidity']] = scaled_df

# %%
X = df.iloc[:,0:7]  #independent columns
y = df.iloc[:,-1]   #target column quality

# %%
bestfeatures=SelectKBest(score_func=chi2,k=7)
fit=bestfeatures.fit(X,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns

# %%
featureScores
# Out:
#          Specs      Score
# 0         Size   9.818910
# 1       Weight   0.000260
# 2    Sweetness  11.162944
# 3  Crunchiness   0.012519
# 4    Juiciness  11.695024
# 5     Ripeness  11.774055
# 6      Acidity   0.010327

# %%
df=df.drop(['Weight','Acidity'],axis=1)

# %%
df #setelah Cleaning Data
# Out:
#           Size  Sweetness  Crunchiness  Juiciness  Ripeness Quality
# 0     0.234669   0.922484     0.368781   0.585819  0.472770    good
# 1     0.439331   0.795706     0.558928   0.511408  0.513807    good
# 2     0.505948   0.388567     0.417732   0.660388  0.444693     bad
# 3     0.479014   0.619422     0.435629   0.720370  0.187052    good
# 4     0.628107   0.490589     0.402347   0.674814  0.348084    good
# ...        ...        ...          ...        ...       ...     ...
# 3995  0.531867   0.239644     0.477379   0.574794  0.618866     bad
# 3996  0.505867   0.504203     0.395971   0.449218  0.364566    good
# 3997  0.333173   0.335661     0.490846   0.612443  0.811182     bad
# 3998  0.231869   0.697913     0.428137   0.609571  0.463966    good
# 3999  0.548031   0.528713     0.358392   0.542429  0.388327    good
#
# [4000 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, 5].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
model = RandomForestClassifier(criterion = "gini", n_estimators = 10)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array(['bad', 'good', 'bad', ..., 'good', 'good', 'bad'], dtype=object)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8366666666666667

# %%
print(model.feature_importances_)
# Out:
# [0.20111934 0.21989595 0.16418337 0.20143638 0.21336496]

# %%
#MENGUJI MODEL DENGAN DATA BARU YANG BELUM PERNAH DI LATIH DAN DI TES SEBELUMNYA

# %%
uji_1=[[1,	1,	0.490846,	0.2,	1],[0.333173,	0.335661,	0.490846,	0.612443,	0.811182],[0,	0.335661,	0.490846,	0.612443,	0.811182]]

# %%
pred=model.predict(uji_1)
pred
# Out:
# array(['good', 'bad', 'bad'], dtype=object)
